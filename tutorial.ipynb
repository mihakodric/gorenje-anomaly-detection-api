# %% [markdown]
# # Import libraries

# %%
from utils.model import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Initialize objects

# %%
parser = Parser()
predictor = HealthCheck()

# %% [markdown]
# # Example prediction

# %%
auid, cycle_settings, cycle_result = parser("input.json")
predictor(cycle_settings, cycle_result, auid)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
